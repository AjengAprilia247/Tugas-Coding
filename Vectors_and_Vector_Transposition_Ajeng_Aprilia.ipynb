# %%
import numpy as np

# %%
# buat vector x dengan ukuran 3x1
x = np.array([19,1,9])
x
# Out:
# array([19,  1,  9])

# %%
# hitung panjang vector x
len(x)
# Out:
# 3

# %%
# tampilkan ukuran vector x
x.shape
# Out:
# (3,)

# %%
# tampilkan tipe data dari vector x
type(x)
# Out:
# numpy.ndarray

# %%
# akses elemen pertama dari vector x
x[0]
# Out:
# np.int64(19)

# %%
# tampilkan tipe data elemen pertama dari vector x
type (x[0])
# Out:
# numpy.int64

# %%
# lakukan transpose pada vector x dan simpan pada variabel x_t
x_t = x.T
x_t
# Out:
# array([19,  1,  9])

# %%
# tampilkan ukuran dari vector x_t
x_t.shape
# Out:
# (3,)

# %%
# buat vector y dengan ukuran 3x1
y = np.array([19,1,9])
y
# Out:
# array([19,  1,  9])

# %%
# lakukan transpose pada vector y dan simpan pada variabel y_t
y_t = y.T
y_t
# Out:
# array([19,  1,  9])

# %%
# tampilkan ukuran dari vector y_t
y_t.shape
# Out:
# (3,)

# %%
# lakukan soal nomor 2 menggunakan pytorch dan tensorflow
import torch
import tensorflow as tf

# %%
# pytorch
y_pt = torch.tensor([19,1,9])
y_pt
# Out:
# tensor([19,  1,  9])

# %%
# Tensorflow
y_tf = tf.Variable([19,1,9])
y_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([19,  1,  9], dtype=int32)>

# %%
# lakukan transpose pada vector y_pt dan simpan pada variabel y_pt_t
y_pt_t = y_pt.T
y_pt_t
# Out:
# /tmp/ipykernel_9083/328932866.py:2: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4480.)
#   y_pt_t = y_pt.T
# tensor([19,  1,  9])

# %%
# lakukan transpose pada vector y_tf dan simpan pada variabel y_tf_t
y_tf_t = tf.transpose(y_tf)
y_tf_t
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([19,  1,  9], dtype=int32)>

# %%
# tampilkan ukuran dari vector y_pt_t
y_pt_t.shape
# Out:
# torch.Size([3])

# %%
# tampilkan ukuran dari vector y_tf_t
y_tf_t.shape
# Out:
# TensorShape([3])
