# %%
import torch

# %%
# selesaikan soal berikut
# what is the transpose of this vector below?
x = torch.tensor([[25],[2],[-3]])
x
# Out:
# tensor([[25],
#         [ 2],
#         [-3]])

# %%
# di transposekan
x = x.T
x
# Out:
# tensor([[25,  2, -3]])
