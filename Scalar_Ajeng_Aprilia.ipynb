# %%
# buat variabel skalar x dan simpan suatu nilai skalar
x = 19
x
# Out:
# 19

# %%
# tampilkan tipe data dari x
type(x)
# Out:
# int

# %%
# buat variabel skalar y dan simpan suatu nilai skalar
y = 19
y
# Out:
# 19

# %%
# tampilkan tipe data dari y
type(y)
# Out:
# int

# %%
# jumlahkan x+y
py_sum = x + y
py_sum
# Out:
# 38

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = 19.0
x_float
# Out:
# 19.0

# %%
# jumlahkan x_float dengan y
x_float = 19.0
float_sum = x_float + y
float_sum
# Out:
# 38.0

# %%
# tampilkan tipe data dari x_float
type(x_float)
# Out:
# float

# %%
import tensorflow as tf

# %%
# buat variabel tensorflow x dan simpan suatu nilai tensorflow
x_tf = tf.Variable (19, dtype=tf.float32)
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=19.0>

# %%
# buat variabel transferflow y dan simpan suatu nilai transferflow
y_tf = tf.Variable (19, dtype=tf.float32)
y_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=19.0>

# %%
# jumlahkan x + y
tf_sum = tf.add(x_tf, y_tf)
tf_sum
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=38>

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_float_tf = tf.Variable (19.0, dytpe=tf.float32)
x_float_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=19.0>

# %%
# jumlahkan x_float dengan y
tf_sum = tf.add(x_float_tf, y_tf)
tf_sum
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=38.0>

# %%
import torch

# %%
# buat variabel skalar x dan simpan suatu nilai skalar
x_pt = torch.tensor(19)
x_pt
# Out:
# tensor(19)

# %%
# tampilkan tipe data dari x
type(x_pt)
# Out:
# torch.Tensor

# %%
# buat variabel skalar x dan simpan suatu nilai skalar
y_pt = torch.tensor(19)
y_pt
# Out:
# tensor(19)

# %%
# tampilkan tipe data dari y
type(y_pt)
# Out:
# torch.Tensor

# %%
# jumlahkan x + y
pt_sum = (x_pt + y_pt)
pt_sum
# Out:
# tensor(38)

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_float_pt = torch.tensor(10.19)
x_float_pt
# Out:
# tensor(10.1900)

# %%
# jumlahkan x_float dengan y
pt_sum = x_float_pt + y_pt
pt_sum
# Out:
# tensor(29.1900)

# %%
# tampilkan tipe data dari x_float
type (x_float_pt)
# Out:
# torch.Tensor
