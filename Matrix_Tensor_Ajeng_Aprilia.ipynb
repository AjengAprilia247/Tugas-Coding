# %%
import numpy as np

# %%
#buat matrix X berukuran 2x3 menggunakan numpy
x = np.array([[19, 2, 4],
              [25, 15, 7]])
x
# Out:
# array([[19,  2,  4],
#        [25, 15,  7]])

# %%
# tampilkan ukuran dari matrix X
x.shape
# Out:
# (2, 3)

# %%
 # tampilkan seluruh elemen dari kolom pertama dari matrix
x[:,0]
# Out:
# array([19, 25])

# %%
# tampilkan seluruh elemen dari baris kedua dari matrix X
x[1,:]
# Out:
# array([25, 15,  7])

# %%
import torch

# %%
# buat matrix X berukuran 2x3 menggunakan pytorch
x_pt = torch.tensor([[19,2,4],
               [25,15,7]])
x_pt
# Out:
# tensor([[19,  2,  4],
#         [25, 15,  7]])

# %%
# tampilkan ukuran dari matrix X
x_pt.shape
# Out:
# torch.Size([2, 3])

# %%
# # tampilkan seluruh elemen dari kolom pertama dari matrix
x_pt[:,0]
# Out:
# tensor([19, 25])

# %%
# tampilkan seluruh elemen dari baris kedua dari matrix
x_pt[1,:]
# Out:
# tensor([25, 15,  7])

# %%
import tensorflow as tf

# %%
# buat matrix x berukuran 2x3 menggunakan tensorflow
x_tf = tf.Variable([[19,2,4],
                    [25,25,7]])
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int32, numpy=
# array([[19,  2,  4],
#        [25, 25,  7]], dtype=int32)>

# %%
# tampilkan ukuran dari matrix x
tf.shape(x_tf)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([2, 3], dtype=int32)>

# %%
 # tampilkan seluruh elemen dari kolom pertama dari matrix x
 x_tf[:,0]
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([19, 25], dtype=int32)>

# %%
# tampilkan seluruh elemen dari baris kedua dari matrix x
x_tf[1,:]
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([25, 25,  7], dtype=int32)>
